# %%
# Here importing all the required libraries for the project:
import torch 
import torch.nn as nn
import cv2 as cv
import numpy as np
import os
import sys
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split

# %%
# Upload the train data:
from torchvision import datasets
full_train_dataset = datasets.ImageFolder(root="C:\\Users\\ravi.dalal\\Desktop\\Python\\Projects\\Defect_Classification\\Datasets\\NEU-DET\\train\\images")

# %%
# Split the trian data into train and val:
train_size = int(0.8 * len(full_train_dataset))
val_size = len(full_train_dataset) - train_size
print(train_size)
print(val_size)
# Out:
# 1152
# 288

# %%
# Random split the train datasets and val datasets:
from torch.utils.data import random_split
train_datasets , val_datasets = random_split(full_train_dataset, [train_size, val_size])

# %%
# Upload the test data:
test_datasets = datasets.ImageFolder("C:\\Users\\ravi.dalal\\Desktop\\Python\\Projects\\Defect_Classification\\Datasets\\NEU-DET\\test\\images")
